# %% [markdown]
# <a href="https://colab.research.google.com/github/lennertjansen/nlp2/blob/master/project1/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount notebook to drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# %cd /content/drive/My\ Drive/nlp2/code
# !ls
# Out:
# /content/drive/My Drive/nlp2/code
# 'Colab Tutorial'   OpenNMT-py

# %% [markdown]
# # OpenNMT Setup
# Taken from: https://github.com/OpenNMT/OpenNMT-py

# %%
# Install OpenNMT-py from pip
# !pip install OpenNMT-py
# Out:
# ...
#      |████████████████████████████████| 194kB 1.4MB/s
# ...
#      |████████████████████████████████| 2.2MB 3.4MB/s
# ...
#      |████████████████████████████████| 51kB 5.2MB/s
# ...
#      |████████████████████████████████| 61kB 5.9MB/s
# ...
#      |████████████████████████████████| 153kB 8.3MB/s
# ...
#      |████████████████████████████████| 51kB 4.8MB/s
# ...
#   Created wheel for configargparse: filename=ConfigArgParse-1.2-cp36-none-any.whl size=19241 sha256=89534a966c1f49328ed66e31df0ff3997aedda798a534316e789146774911a8c
#   Stored in directory: /root/.cache/pip/wheels/54/a9/fd/158b17e2bce41b6d6a3ed4e5bc4ae99602d06632f2678c5407
# Successfully built configargparse
# ERROR: spacy 2.2.4 has requirement tqdm<5.0.0,>=4.38.0, but you'll have tqdm 4.30.0 which is incompatible.
# ...
#   Found existing installation: tqdm 4.38.0
#     Uninstalling tqdm-4.38.0:
#       Successfully uninstalled tqdm-4.38.0
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
# ...

# %% [markdown]
# # OpenNMT-py Tutorial with Sample Data

# %%
# Full installation from source repo
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# %cd OpenNMT-py
# !ls

# !python setup.py install
# Out:
# fatal: destination path 'OpenNMT-py' already exists and is not an empty directory.
# /content/drive/My Drive/nlp2/code/OpenNMT-py
# available_models			  LICENSE.md
# build					  onmt
# CHANGELOG.md				  OpenNMT_py.egg-info
# config					  preprocess.py
# CONTRIBUTING.md				  README.md
# data					  requirements.opt.txt
# dist					  server.py
# docs					  setup.py
# floyd_requirements.txt			  tools
# floyd.yml				  train.py
# github_deploy_key_opennmt_opennmt_py.enc  translate.py
# running install
# running bdist_egg
# running egg_info
# writing OpenNMT_py.egg-info/PKG-INFO
# writing dependency_links to OpenNMT_py.egg-info/dependency_links.txt
# writing entry points to OpenNMT_py.egg-info/entry_points.txt
# writing requirements to OpenNMT_py.egg-info/requires.txt
# writing top-level names to OpenNMT_py.egg-info/top_level.txt
# writing manifest file 'OpenNMT_py.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# ...

# %% [markdown]
# # Step 1: Preprocessing the data
# Working with example data in `data/` folder
#
# NB: preprocessed data is saved in `data/` as, e.g., `demo.train.pt`

# %%
# !onmt_preprocess -train_src data/src-train.txt -train_tgt data/tgt-train.txt -valid_src data/src-val.txt -valid_tgt data/tgt-val.txt -save_data data/demo
# Out:
# [2020-04-09 06:59:58,827 INFO] Extracting features...
# [2020-04-09 07:00:00,056 INFO]  * number of source features: 0.
# [2020-04-09 07:00:00,056 INFO]  * number of target features: 0.
# [2020-04-09 07:00:00,056 INFO] Building `Fields` object...
# [2020-04-09 07:00:00,057 INFO] Building & saving training data...
# [2020-04-09 07:00:00,061 WARNING] Shards for corpus train already exist, won't be overwritten, pass the `-overwrite` option if you want to.
# [2020-04-09 07:00:00,061 INFO] Building & saving validation data...
# [2020-04-09 07:00:00,062 WARNING] Shards for corpus valid already exist, won't be overwritten, pass the `-overwrite` option if you want to.

# %% [markdown]
# # Step 2: Train the model

# %%
# !onmt_train -data data/demo -save_model demo-model -train_steps 1000
# Out:
# You have a CUDA device, should run with -gpu_ranks
# [2020-04-09 07:00:09,034 INFO]  * src vocab size = 24997
# [2020-04-09 07:00:09,034 INFO]  * tgt vocab size = 35820
# [2020-04-09 07:00:09,034 INFO] Building model...
# [2020-04-09 07:00:10,010 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(24997, 500, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(500, 500, num_layers=2, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(35820, 500, padding_idx=1)
#         )
#       )
#     )
#     (dropout): Dropout(p=0.3, inplace=False)
#     (rnn): StackedLSTM(
#       (dropout): Dropout(p=0.3, inplace=False)
#       (layers): ModuleList(
#         (0): LSTMCell(1000, 500)
#         (1): LSTMCell(500, 500)
#       )
# ...

# %% [markdown]
# # Step 3: Translate

# %%
# !onmt_translate -model demo-model_step_1000.pt -src data/src-test.txt -output pred.txt -replace_unk -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# PRED 1488: Es ist nicht der Kommission .
# PRED SCORE: -15.9255
#
# SENT 1489: ['Once', 'he', 'has', 'collected', 'the', 'key', 'from', 'the', 'information', 'desk', ',', 'he', 'leads', 'the', 'group', 'to', 'a', '16-metre', ',', 'accessible', 'shaft', '.']
# PRED 1489: Es ist nicht der Kommission für die Verfassung für die Verfassung der Union in der Nähe der Europäischen Union .
# PRED SCORE: -54.3984
#
# SENT 1490: ['&quot;', 'We', 'are', 'now', 'in', 'the', 'Mikwe', ',', 'a', 'ritual', 'Jewish', 'bath', ',', '&quot;', 'he', 'explains', '.']
# PRED 1490: Es gibt es für die Verfassung in der Nähe der Europäischen Union .
# PRED SCORE: -33.6648
#
# SENT 1491: ['The', 'Jewish', 'congregation', 'built', 'their', 'bath', 'deep', 'into', 'the', 'ground', 'in', 'order', 'to', 'reach', 'the', 'groundwater', 'essential', 'for', 'ritual', 'washing', '.']
# ...
